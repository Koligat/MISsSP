# %%
import pulp
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train = pd.DataFrame.from_csv('train.csv')

train
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:1: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   """Entry point for launching an IPython kernel.
#       age            job   marital  education default  balance housing loan  \
# 0      60       services   married   tertiary      no     4256     yes   no
# 1      25        student    single  secondary      no      154      no   no
# 2      38       services   married  secondary      no      507     yes   no
# 3      40     management    single   tertiary      no     1361      no   no
# 4      39     technician   married  secondary      no      834     yes  yes
# 5      36     management   married   tertiary      no     2987     yes   no
# 6      40   entrepreneur   married   tertiary      no     1953     yes   no
# 7      51       services    single  secondary      no      513     yes   no
# 8      51        retired   married    primary      no     1495      no   no
# 9      38     management    single   tertiary      no     6836     yes   no
# 10     45     management   married  secondary      no     5888     yes   no
# 11     55     technician   married  secondary      no      264     yes  yes
# 12     45        retired  divorced  secondary      no     1735      no  yes
# 13     47     management   married   tertiary      no      682      no   no
# 14     33       services    single   tertiary      no     -452      no   no
# 15     39     management    single   tertiary      no     2258     yes   no
# 16     29    blue-collar    single  secondary      no      922     yes   no
# 17     34     management    single   tertiary      no      275      no   no
# 18     36         admin.   married  secondary      no        0     yes  yes
# 19     31     management    single   tertiary      no    12857     yes   no
# 20     59     technician  divorced  secondary      no     2595     yes   no
# 21     36         admin.   married   tertiary      no      211     yes   no
# 22     60     technician   married   tertiary      no       91      no   no
# 23     34    blue-collar   married  secondary      no     1988     yes   no
# 24     60         admin.   married  secondary      no     3547      no   no
# 25     27    blue-collar   married  secondary      no      419     yes   no
# 26     51     technician   married  secondary      no     2682      no   no
# 27     39     technician   married   tertiary      no     1524      no   no
# 28     47     management   married   tertiary      no     2351      no   no
# 29     34      housemaid   married   tertiary      no     1265     yes   no
# ...   ...            ...       ...        ...     ...      ...     ...  ...
# 8006   49    blue-collar   married    primary      no      361     yes   no
# 8007   34     management   married  secondary      no     -311     yes   no
# 8008   59         admin.   married  secondary      no     4196      no   no
# 8009   48         admin.    single  secondary      no     1544     yes   no
# 8010   38     management  divorced   tertiary      no     6368     yes   no
# 8011   40     technician   married   tertiary      no     1034     yes   no
# 8012   33         admin.   married  secondary      no      920      no   no
# 8013   58        retired   married    primary      no     5092      no   no
# 8014   52    blue-collar   married    primary      no     1271      no   no
# 8015   36     technician  divorced  secondary      no       54     yes   no
# 8016   49       services   married  secondary      no      823      no   no
# 8017   52     management   married    unknown      no     2240     yes   no
# 8018   45    blue-collar   married    primary      no     1558     yes   no
# 8019   43  self-employed    single    primary      no     1337     yes  yes
# 8020   33         admin.    single  secondary      no     1221     yes   no
# 8021   47         admin.  divorced  secondary      no      555     yes  yes
# 8022   32     management   married   tertiary      no     2431     yes   no
# 8023   35    blue-collar    single    primary      no     2040      no   no
# 8024   37     management   married   tertiary      no       57      no   no
# 8025   32         admin.   married  secondary      no     3540     yes   no
# 8026   34    blue-collar   married    primary      no      425     yes   no
# 8027   42    blue-collar   married    primary      no      170     yes   no
# 8028   60        retired   married   tertiary      no     2196      no   no
# 8029   36        student    single   tertiary      no      129      no   no
# 8030   25    blue-collar   married  secondary      no       97     yes   no
# 8031   59        retired  divorced    primary      no      -88     yes   no
# 8032   35     technician  divorced  secondary      no     5724     yes   no
# 8033   32    blue-collar   married  secondary      no      759     yes   no
# 8034   50     management   married   tertiary      no     1612      no   no
# 8035   33     management    single   tertiary      no     1150     yes   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# 0      cellular   16   aug       239         3    761         1    other
# 1      cellular    3   mar       141         1    180         2  failure
# 2      cellular   17   apr        55         1    344         1  failure
# 3      cellular   29   jan      1473         1     -1         0  unknown
# 4      cellular   20   apr       390         1     -1         0  unknown
# 5      cellular   12   aug       307         1     -1         0  unknown
# 6       unknown    6   jun       112         5     -1         0  unknown
# 7      cellular   29   jul       331         2     -1         0  unknown
# 8     telephone   25   jul      1946         4     -1         0  unknown
# 9       unknown   29   may       374         4     -1         0  unknown
# 10      unknown   26   may        45         5     -1         0  unknown
# 11     cellular   31   jul      1150         5     -1         0  unknown
# 12      unknown   17   jun       306         1     -1         0  unknown
# 13     cellular   18   aug       638         6     -1         0  unknown
# 14     cellular   29   jan       692         2     -1         0  unknown
# 15     cellular   31   jul       255         2     -1         0  unknown
# 16     cellular   18   may        72         1     -1         0  unknown
# 17     cellular    2   aug       196         2    455        23    other
# 18     cellular   11   may        94         1     -1         0  unknown
# 19     cellular    6   feb       158         1     92         1  success
# 20     cellular   29   aug       398         2     -1         0  unknown
# 21      unknown    5   may       146         2     -1         0  unknown
# 22     cellular   27   aug       105         4     -1         0  unknown
# 23    telephone   29   jan        53         1    266         2  failure
# 24    telephone   15   jun       351         6     -1         0  unknown
# 25      unknown    4   jun      1181         2     -1         0  unknown
# 26      unknown   18   jun        56         1     -1         0  unknown
# 27     cellular   20   apr       567         1     -1         0  unknown
# 28     cellular   10   mar        80         1     -1         0  unknown
# 29      unknown    6   jun       397         3     -1         0  unknown
# ...         ...  ...   ...       ...       ...    ...       ...      ...
# 8006    unknown   16   jun       513         2     -1         0  unknown
# 8007    unknown   27   may       305         2     -1         0  unknown
# 8008  telephone   31   jul        10         2     -1         0  unknown
# 8009  telephone   30   jun       263         1    450         2  failure
# 8010   cellular    4   may       922         4     -1         0  unknown
# 8011   cellular   18   may       368         2     -1         0  unknown
# 8012   cellular   16   nov       130         1     95         2  failure
# 8013    unknown   11   jun       199         6     -1         0  unknown
# 8014   cellular   18   aug       131         3     -1         0  unknown
# 8015   cellular   27   aug      1642         3     -1         0  unknown
# 8016   cellular    8   aug       780         4     -1         0  unknown
# 8017    unknown   13   may       845         1     -1         0  unknown
# 8018   cellular    6   may       179         1     -1         0  unknown
# 8019   cellular   20   nov       632         2     -1         0  unknown
# 8020    unknown   23   may       245         1     -1         0  unknown
# 8021  telephone   17   oct       478         1     -1         0  unknown
# 8022   cellular   14   may       646         5     -1         0  unknown
# 8023   cellular   21   nov       258         1    157         4  failure
# 8024   cellular   30   apr        96         2     84         1  success
# 8025   cellular   18   may       213         1    178         1  failure
# 8026   cellular   16   jul      1389         7     -1         0  unknown
# 8027    unknown   19   may        51        41     -1         0  unknown
# 8028   cellular   15   jun       318         3     -1         0  unknown
# 8029   cellular   28   jan       918         1     93         1  success
# 8030    unknown   27   may       709         1     -1         0  unknown
# 8031    unknown    5   jun       910         2     -1         0  unknown
# 8032    unknown   30   may       691        10     -1         0  unknown
# 8033   cellular    9   apr       317         5     -1         0  unknown
# 8034   cellular   15   jun       532         2     98         2    other
# 8035  telephone   12   may       109         2     -1         0  unknown
#
#      deposit
# 0        yes
# 1        yes
# 2         no
# 3        yes
# 4         no
# 5        yes
# 6         no
# 7         no
# 8        yes
# 9         no
# 10        no
# 11       yes
# 12        no
# 13       yes
# 14       yes
# 15        no
# 16        no
# 17       yes
# 18        no
# 19       yes
# 20        no
# 21        no
# 22        no
# 23        no
# 24       yes
# 25       yes
# 26        no
# 27       yes
# 28       yes
# 29        no
# ...      ...
# 8006     yes
# 8007      no
# 8008      no
# 8009     yes
# 8010     yes
# 8011      no
# 8012     yes
# 8013      no
# 8014      no
# 8015     yes
# 8016     yes
# 8017     yes
# 8018      no
# 8019      no
# 8020      no
# 8021     yes
# 8022     yes
# 8023      no
# 8024      no
# 8025      no
# 8026      no
# 8027      no
# 8028      no
# 8029     yes
# 8030     yes
# 8031     yes
# 8032     yes
# 8033     yes
# 8034     yes
# 8035      no
#
# [8036 rows x 17 columns]

# %%
df = pd.read_csv('train.csv')

# %%
df.tail()
# Out:
#       Unnamed: 0  age          job   marital  education default  balance  \
# 8031        8031   59      retired  divorced    primary      no      -88
# 8032        8032   35   technician  divorced  secondary      no     5724
# 8033        8033   32  blue-collar   married  secondary      no      759
# 8034        8034   50   management   married   tertiary      no     1612
# 8035        8035   33   management    single   tertiary      no     1150
#
#      housing loan    contact  day month  duration  campaign  pdays  previous  \
# 8031     yes   no    unknown    5   jun       910         2     -1         0
# 8032     yes   no    unknown   30   may       691        10     -1         0
# 8033     yes   no   cellular    9   apr       317         5     -1         0
# 8034      no   no   cellular   15   jun       532         2     98         2
# 8035     yes   no  telephone   12   may       109         2     -1         0
#
#      poutcome deposit
# 8031  unknown     yes
# 8032  unknown     yes
# 8033  unknown     yes
# 8034    other     yes
# 8035  unknown      no

# %%
# %matplotlib inline
plt.figure(); df.plot()

# %%
wszystkie=np.array(train)
x=wszystkie[:,:-1]
y=wszystkie[:,-1]

# %%
x
# Out:
# array([[60, 'services', 'married', ..., 761, 1, 'other'],
#        [25, 'student', 'single', ..., 180, 2, 'failure'],
#        [38, 'services', 'married', ..., 344, 1, 'failure'],
#        ...,
#        [32, 'blue-collar', 'married', ..., -1, 0, 'unknown'],
#        [50, 'management', 'married', ..., 98, 2, 'other'],
#        [33, 'management', 'single', ..., -1, 0, 'unknown']], dtype=object)

# %%
y
# Out:
# array(['yes', 'yes', 'no', ..., 'yes', 'yes', 'no'], dtype=object)

# %%
sns.factorplot('job',data=df,kind='count')

# %%
fig, ax = plt.subplots(1,2,figsize = (18, 8))
train["job"].value_counts().plot.bar(color = "skyblue", ax = ax[0])
ax[0].set_ylabel("count")
plt.show()
